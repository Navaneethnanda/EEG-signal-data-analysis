# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data=np.load("/content/drive/My Drive/Colab Notebooks/whole/data.npy", mmap_mode=None, allow_pickle=True, fix_imports=True, encoding='ASCII')

# %%
data.shape
# Out:
# (1280, 34160)

# %%
labels=np.load("/content/drive/My Drive/Colab Notebooks/whole/labels.npy", mmap_mode=None, allow_pickle=True, fix_imports=True, encoding='ASCII')

# %%
labels.shape
# Out:
# (1280, 4)

# %% [markdown]
# # valence

# %%
y1=labels[:,0]
y1
# Out:
# array([7.71, 8.1 , 8.58, ..., 3.05, 3.99, 7.15])

# %%
y1=(y1>5).astype(int)

# %%
y1
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
X=data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
X=scalar.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y1_train,y1_test=train_test_split(X,y1,test_size=20,random_state=21)

# %%
from sklearn import svm

# %%
clf1 = svm.SVC()
clf1.fit(X_train, y1_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf1.score(X_test,y3_test)
# Out:
# 0.6

# %% [markdown]
# # arousal

# %%
y2=labels[:,1]
y2
# Out:
# array([7.6 , 7.31, 7.54, ..., 7.01, 7.17, 4.03])

# %%
y2=(y2>5).astype(int)

# %%
y2
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
X=data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
X=scalar.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y2_train,y2_test=train_test_split(X,y2,test_size=20,random_state=21)

# %%
from sklearn import svm

# %%
clf2 = svm.SVC()
clf2.fit(X_train, y2_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf2.score(X_test,y2_test)
# Out:
# 0.65

# %% [markdown]
# # Liking

# %%
y4=labels[:,3]
y4
# Out:
# array([7.83, 8.47, 7.08, ..., 1.1 , 1.  , 1.88])

# %%
y4=(y4>5).astype(int)

# %%
y4
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
X=data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
X=scalar.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y4_train,y4_test=train_test_split(X,y4,test_size=20,random_state=21)

# %%
from sklearn import svm

# %%
clf4 = svm.SVC()
clf4.fit(X_train, y4_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf4.score(X_test,y4_test)
# Out:
# 0.65

# %% [markdown]
# # dominance

# %%
y3=labels[:,2]
y3
# Out:
# array([6.9 , 7.28, 9.  , ..., 5.1 , 4.85, 9.  ])

# %%
y3=(y3>5).astype(int)

# %%
y3
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
X=data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
X=scalar.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y3_train,y3_test=train_test_split(X,y3,test_size=20,random_state=21)

# %%
from sklearn import svm

# %%
clf3 = svm.SVC()
clf3.fit(X_train, y3_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf3.score(X_test,y3_test)
# Out:
# 0.6
